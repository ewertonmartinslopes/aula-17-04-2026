# %% [markdown]
# <a href="https://colab.research.google.com/github/ewertonmartinslopes/aula-17-04-2026/blob/main/C%C3%B3pia_de_Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
idade = int(input('digite sua idade:'))
if idade >= 18:
  print('você é maior de idade:')
else:
  print('você é menor de idade:')
# Out:
# digite sua idade:15
# você é menor de idade:

# %%
idade = 14
if idade < 16:
  print('você é menor de idade')
elif idade >=16 and idade <18:
  print('voto opcional')
elif idade >=18 and idade <=75:
  print('voto obrigatorio')
else:
  print('nenhuma das opções')
# Out:
# você é menor de idade

# %%
venda = float(input('digite suas vendas:'))
meta = float(input('digite sua meta:'))
meta2 = float(input('digite sua meta:'))
if venda >= meta2:
  bonus = 0.13 * venda
elif venda >= meta:
  bonus = 0.1 * venda
else:
  bonus = 0
print('bonus:', bonus)
# Out:
# digite suas vendas:2100
# digite sua meta:1300
# digite sua meta:2000
# bonus: 273.0

# %%
#ATIVIDADE 3
entrega= input('digite o tipo de entrega:')
if entrega == 'padrão':
  print('entrega padrão: R$10,00')
elif entrega == 'expresso':
  print('entrega expresso: R$20,00')
else:
  print('opção de entrega invalida')
# Out:
# digite o tipo de entrega:expresso
# entrega expresso: R$20,00
